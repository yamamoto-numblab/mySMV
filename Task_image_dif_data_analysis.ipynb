# %%
import os
import numpy as np
import pandas as pd
import mne
import scipy.io
import matplotlib.pyplot as plt
from scipy import signal
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from mne.decoding import CSP
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import FastICA
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neural_network import MLPClassifier

# %%
#filePath= '/Users/yaman/Library/CloudStorage/GoogleDrive-s203192@stn.nagaokaut.ac.jp/マイドライブ/実験データ/20230519_zikken'
#filePath= '/Users/yaman/Library/CloudStorage/GoogleDrive-s203192@stn.nagaokaut.ac.jp/マイドライブ/実験データ/20230529_1_zikken'
#filePath= '/Users/yaman/Library/CloudStorage/GoogleDrive-s203192@stn.nagaokaut.ac.jp/マイドライブ/実験データ/20230620_zikken'
#filePath= '/Users/yaman/Library/CloudStorage/GoogleDrive-s203192@stn.nagaokaut.ac.jp/マイドライブ/実験データ/20230622_zikken'
filePath= '/Users/yaman/Library/CloudStorage/GoogleDrive-s203192@stn.nagaokaut.ac.jp/マイドライブ/実験データ/20230713'


# filePath = 'G:/マイドライブ/実験データ/20230519_zikken'
brainAdress = ['Fp1','AF7','AF3','F1','F3','F5','F7','FT7','FC5',
'FC3','FC1','C1','C3','C5','T7','TP7','CP5','CP3','CP1','P1','P3',
'P5','P7','P9','PO7','PO3','O1','Iz','Oz','POz','Pz','CPz','Fpz','Fp2',
'AF8','AF4','AFz','Fz','F2','F4','F6','F8','FT8','FC6','FC4','FC2',
'FCz','Cz','C2','C4','C6','T8','TP8','CP6','CP4','CP2','P2','P4',
'P6','P8','P10','PO8','PO4','O2']



motor_brainAdress = [9,10,11,12,13,17,18,31,44,45,46,47,48,49,50,54,55]




# dataクラス
class O_Data:
    def __init__(self, eeg, index, label):
        self.eeg = eeg
        self.index = index
        self.label = label
        self.stack = []

    def push(self, item):
        self.stack.append(item)

o_data65_label1 = list()#label1のデータ
o_data = list()
label_data = list()#labelを結合したデータ


All_data = list()  # 全データを結合

def Standardization(data): #標準化
    after_data = scipy.stats.zscore(data)
    #b = np.average(after_data)
    #c = np.var(after_data)
    return after_data

file_name = list()  # すべての.matファイルの名前
for file in os.listdir(filePath):
    base, ext = os.path.splitext(file)
    if ext == '.mat':
        file_name = sorted(file_name)
        file_name.append(file)
print('Filelist')
print(file_name)
# Out:
# Filelist
# ['EEG_grasping_13-Jul-2023_sub1-1.mat', 'EEG_grasping_13-Jul-2023_sub1-2.mat', 'EEG_grasping_13-Jul-2023_sub2-1.mat', 'EEG_grasping_13-Jul-2023_sub2-3.mat', 'EEG_grasping_13-Jul-2023_sub2-4.mat', 'EEG_grasping_13-Jul-2023_sub3-1.mat', 'EEG_grasping_13-Jul-2023_sub3-2.mat', 'EEG_grasping_13-Jul-2023_sub3-3.mat', 'EEG_grasping_13-Jul-2023_sub3-4.mat', 'EEG_grasping_13-Jul-2023_sub2-2.mat']

# %%
#解析するデータを選択
#file_name1 = [file_name[6],file_name[7],file_name[8],file_name[9]]
file_name1 = [file_name[5],file_name[6],file_name[7],file_name[8]]
file_num1 = len(file_name1)
trial_num = 30
all_trial = len(file_name1) * trial_num
all_d = 0
CH = 64
#label1を読み込む
for s in range(file_num1):
    Dictionary = scipy.io.loadmat(filePath+"/"+file_name1[s])
    for t in range(trial_num):
        for i, key in enumerate(Dictionary.keys()):
            if i > 2:
                a = Dictionary[key]
                b = a[0, t][0][0]
                eeg = b[0][0:66, :]
                index = b[1]
                samplerate = b[2]
                label = b[5][0, 0]
                o_data = O_Data(eeg, index, label)
                o_data65_label1.append(o_data)
print("image data_loading")
print(file_name1)
# Out:
# image data_loading
# ['EEG_grasping_13-Jul-2023_sub3-1.mat', 'EEG_grasping_13-Jul-2023_sub3-2.mat', 'EEG_grasping_13-Jul-2023_sub3-3.mat', 'EEG_grasping_13-Jul-2023_sub3-4.mat']

# %%
c1 = o_data65_label1[0].eeg[0:64 , 0:10240]
for n in range(len(file_name1)*trial_num-1):  # all_trial
    g1 = o_data65_label1[n+1].eeg[0:64 , 0:10240]
    c1 = np.dstack([c1, g1])
all_data = c1.transpose(2,0,1)
print(np.shape(all_data))
all_data = all_data.astype(np.double)
# Out:
# (120, 64, 10240)

# %%
label_data = list()#labelを結合したデータ
for n in range(all_trial):
    label_data.append(o_data65_label1[n].label)
print(label_data)
print(np.shape(label_data))
# Out:
# [1, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 1, 1, 1, 1, 2, 2, 1, 2, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2, 1, 1, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 1, 1, 2, 2, 1, 2, 1, 1, 2, 1, 1, 2, 1, 1, 1, 1, 2, 1, 2, 2, 2, 2, 2, 1, 1, 1, 1, 2, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 2, 1, 1, 1, 1, 2, 1, 1, 2, 2, 1, 2, 2, 2, 1, 1, 2, 2, 2, 1, 2, 1, 1, 1, 2, 2, 1]
# (120,)

# %%
n_channels = 64
sampling_freq = 1024  # in Hertz
info = mne.create_info(ch_names=brainAdress, ch_types="eeg", sfreq=sampling_freq)
info.set_montage('biosemi64')
data = mne.EpochsArray(all_data,info=info)
# Out:
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
mne.find_events(all_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/yaman/Documents/書類 - 山本航平のMacBook Air/GitHub/mySMV/Task_image_dif_data_analysis.ipynb セル 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yaman/Documents/%E6%9B%B8%E9%A1%9E%20-%20%E5%B1%B1%E6%9C%AC%E8%88%AA%E5%B9%B3%E3%81%AEMacBook%20Air/GitHub/mySMV/Task_image_dif_data_analysis.ipynb#Y116sZmlsZQ%3D%3D?line=0'>1</a> mne.find_events(all_data)
#
# File <decorator-gen-182>:12, in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/event.py:687, in find_events(raw, stim_channel, output, consecutive, min_duration, shortest_event, mask, uint_cast, mask_type, initial_event, verbose)
#     536 @verbose
#     537 def find_events(raw, stim_channel=None, output='onset',
#     538                 consecutive='increasing', min_duration=0,
#     539                 shortest_event=2, mask=None, uint_cast=False,
#     540                 mask_type='and', initial_event=False, verbose=None):
#     541     """Find :term:`events` from raw file.
#     542
#     543     See :ref:`tut-events-vs-annotations` and :ref:`tut-event-arrays`
#    (...)
#     685               2 '0000010'
#     686     """
# --> 687     min_samples = min_duration * raw.info['sfreq']
#     689     # pull stim channel from config if necessary
#     690     try:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
data_flit = data.filter(l_freq=1.0,h_freq=40)
ica = mne.preprocessing.ICA(n_components=20,random_state=42,max_iter=800)
ica.fit(data_flit)
ica.exclude = [1,2]
ica.plot_properties(data_flit,picks=ica.exclude)
# Out:
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 3381 samples (3.302 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Fitting ICA to data using 64 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done 7680 out of 7680 | elapsed:    4.5s finished
# Selecting by number: 20 components
# Fitting ICA took 22.8s.
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 120 matching events found
# No baseline correction applied
# 0 projection items activated
# [<Figure size 700x600 with 6 Axes>, <Figure size 700x600 with 6 Axes>]

# %%
data_ica = data.copy()
ica.apply(data_ica)
data_ICA_flit = data_ica.get_data()
np.shape(data_ICA_flit)
# Out:
# Applying ICA to Epochs instance
#     Transforming to ICA space (20 components)
#     Zeroing out 2 ICA components
#     Projecting back using 64 PCA components
# (120, 64, 10240)

# %%
#numpy配列の定義
task1 = data_ICA_flit[0,:,0:10240]
task2 = data_ICA_flit[0,:,0:10240]
for n in range(all_trial):
    if label_data[n] == 1:
        join = data_ICA_flit[n,: , 0:10240]
        task1 = np.dstack([task1, join])
    if label_data[n] == 2:
        join = data_ICA_flit[n,: , 0:10240]
        task2 = np.dstack([task2, join])
#task1低速度
task1_data = task1.transpose(2,0,1)
task1_data = task1_data.astype(np.double)
task1_data = np.delete(task1_data,0,axis=0)
print(np.shape(task1_data))
#task2低速度
task2_data = task2.transpose(2,0,1)
task2_data = task2_data.astype(np.double)
task2_data = np.delete(task2_data,0,axis=0)
print(np.shape(task2_data))
# Out:
# (60, 64, 10240)
# (60, 64, 10240)

# %%
processed_task1 = task1_data[:,range(64),1024*8:1024*10]
processed_task2 = task2_data[:,range(64),1024*8:1024*10]

csp_train1 = task1_data[:,range(64),1024*6:1024*8]
csp_train2 = task2_data[:,range(64),1024*6:1024*8]

# %%
class_data = np.concatenate([processed_task1,processed_task2])
csp_class_data = np.concatenate([csp_train1,csp_train2])
class_label = np.zeros(120,dtype=int)
class_label[60:] = 1

# %%
np.shape(class_data)
# Out:
# (120, 64, 2048)

# %%
#時系列データのSVM
class_data_reshape = np.reshape(class_data,(120,64*1024*2))
X_train, X_test, Y_train, Y_test = train_test_split(class_data_reshape,class_label, test_size=0.25,random_state=42)
model =SVC(kernel='linear')
model.fit(X_train,Y_train)
print(model.score(X_test, Y_test))
# Out:
# 0.4666666666666667

# %%
# Assemble a classifier
lda = LinearDiscriminantAnalysis()
#csp = CSP(n_components=2, log=None, reg=None)
csp = CSP(n_components=8, reg=None, norm_trace=False, transform_into='average_power',cov_est='epoch')

# %%
# plot CSP patterns estimated on full data for visualization
csp.fit_transform(csp_class_data, class_label)
csp.plot_patterns(info,ch_type='eeg', units='None', size=1.5)
# Out:
# Computing rank from data with rank=None
#     Using tolerance 61 (2.2e-16 eps * 64 dim * 4.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 70 (2.2e-16 eps * 64 dim * 5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 82 (2.2e-16 eps * 64 dim * 5.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 79 (2.2e-16 eps * 64 dim * 5.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 90 (2.2e-16 eps * 64 dim * 6.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 83 (2.2e-16 eps * 64 dim * 5.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 87 (2.2e-16 eps * 64 dim * 6.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 67 (2.2e-16 eps * 64 dim * 4.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 96 (2.2e-16 eps * 64 dim * 6.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 76 (2.2e-16 eps * 64 dim * 5.4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 44 (2.2e-16 eps * 64 dim * 3.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 96 (2.2e-16 eps * 64 dim * 6.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 99 (2.2e-16 eps * 64 dim * 7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 79 (2.2e-16 eps * 64 dim * 5.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 91 (2.2e-16 eps * 64 dim * 6.4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 77 (2.2e-16 eps * 64 dim * 5.4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 78 (2.2e-16 eps * 64 dim * 5.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 56 (2.2e-16 eps * 64 dim * 4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 95 (2.2e-16 eps * 64 dim * 6.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3e+02 (2.2e-16 eps * 64 dim * 9.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 43 (2.2e-16 eps * 64 dim * 3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 62 (2.2e-16 eps * 64 dim * 4.4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 98 (2.2e-16 eps * 64 dim * 6.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e+02 (2.2e-16 eps * 64 dim * 8.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 97 (2.2e-16 eps * 64 dim * 6.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e+02 (2.2e-16 eps * 64 dim * 9.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 98 (2.2e-16 eps * 64 dim * 6.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3e+02 (2.2e-16 eps * 64 dim * 9.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 54 (2.2e-16 eps * 64 dim * 3.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 99 (2.2e-16 eps * 64 dim * 7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 30 (2.2e-16 eps * 64 dim * 2.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 52 (2.2e-16 eps * 64 dim * 3.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 89 (2.2e-16 eps * 64 dim * 6.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 97 (2.2e-16 eps * 64 dim * 6.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 95 (2.2e-16 eps * 64 dim * 6.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 99 (2.2e-16 eps * 64 dim * 6.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e+02 (2.2e-16 eps * 64 dim * 8.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 96 (2.2e-16 eps * 64 dim * 6.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3e+02 (2.2e-16 eps * 64 dim * 9.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e+02 (2.2e-16 eps * 64 dim * 8.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 88 (2.2e-16 eps * 64 dim * 6.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 60 (2.2e-16 eps * 64 dim * 4.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 24 (2.2e-16 eps * 64 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 70 (2.2e-16 eps * 64 dim * 4.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 36 (2.2e-16 eps * 64 dim * 2.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 31 (2.2e-16 eps * 64 dim * 2.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 42 (2.2e-16 eps * 64 dim * 3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 54 (2.2e-16 eps * 64 dim * 3.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 31 (2.2e-16 eps * 64 dim * 2.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 50 (2.2e-16 eps * 64 dim * 3.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 97 (2.2e-16 eps * 64 dim * 6.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 8.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 88 (2.2e-16 eps * 64 dim * 6.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 78 (2.2e-16 eps * 64 dim * 5.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 96 (2.2e-16 eps * 64 dim * 6.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e+02 (2.2e-16 eps * 64 dim * 8.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 95 (2.2e-16 eps * 64 dim * 6.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 97 (2.2e-16 eps * 64 dim * 6.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 65 (2.2e-16 eps * 64 dim * 4.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 92 (2.2e-16 eps * 64 dim * 6.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 88 (2.2e-16 eps * 64 dim * 6.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 66 (2.2e-16 eps * 64 dim * 4.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 97 (2.2e-16 eps * 64 dim * 6.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 84 (2.2e-16 eps * 64 dim * 5.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 70 (2.2e-16 eps * 64 dim * 4.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 95 (2.2e-16 eps * 64 dim * 6.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 98 (2.2e-16 eps * 64 dim * 6.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3e+02 (2.2e-16 eps * 64 dim * 9.3e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.7e+02 (2.2e-16 eps * 64 dim * 1.2e+16  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 89 (2.2e-16 eps * 64 dim * 6.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 59 (2.2e-16 eps * 64 dim * 4.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 99 (2.2e-16 eps * 64 dim * 7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 81 (2.2e-16 eps * 64 dim * 5.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e+02 (2.2e-16 eps * 64 dim * 8.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e+02 (2.2e-16 eps * 64 dim * 7.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 8.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 82 (2.2e-16 eps * 64 dim * 5.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 72 (2.2e-16 eps * 64 dim * 5.1e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 51 (2.2e-16 eps * 64 dim * 3.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 63 (2.2e-16 eps * 64 dim * 4.4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.5e+02 (2.2e-16 eps * 64 dim * 1.1e+16  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 98 (2.2e-16 eps * 64 dim * 6.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e+02 (2.2e-16 eps * 64 dim * 1e+16  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e+02 (2.2e-16 eps * 64 dim * 9.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e+02 (2.2e-16 eps * 64 dim * 7.8e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 81 (2.2e-16 eps * 64 dim * 5.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e+02 (2.2e-16 eps * 64 dim * 8.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 98 (2.2e-16 eps * 64 dim * 6.9e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e+02 (2.2e-16 eps * 64 dim * 8.6e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 57 (2.2e-16 eps * 64 dim * 4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e+02 (2.2e-16 eps * 64 dim * 8.2e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 99 (2.2e-16 eps * 64 dim * 7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 63 (2.2e-16 eps * 64 dim * 4.4e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 93 (2.2e-16 eps * 64 dim * 6.5e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 96 (2.2e-16 eps * 64 dim * 6.7e+15  max singular value)
#     Estimated rank (mag): 63
#     MAG: rank 63 computed from 64 data channels with 0 projectors
#     Setting small MAG eigenvalues to zero (without PCA)
# Reducing data rank from 64 -> 63
# Estimating covariance using EMPIRICAL
# Done.
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /Users/yaman/Documents/書類 - 山本航平のMacBook Air/GitHub/mySMV/Task_image_dif_data_analysis.ipynb セル 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/yaman/Documents/%E6%9B%B8%E9%A1%9E%20-%20%E5%B1%B1%E6%9C%AC%E8%88%AA%E5%B9%B3%E3%81%AEMacBook%20Air/GitHub/mySMV/Task_image_dif_data_analysis.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> # plot CSP patterns estimated on full data for visualization
# ----> <a href='vscode-notebook-cell:/Users/yaman/Documents/%E6%9B%B8%E9%A1%9E%20-%20%E5%B1%B1%E6%9C%AC%E8%88%AA%E5%B9%B3%E3%81%AEMacBook%20Air/GitHub/mySMV/Task_image_dif_data_analysis.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> csp.fit_transform(csp_class_data, class_label)
#       <a href='vscode-notebook-cell:/Users/yaman/Documents/%E6%9B%B8%E9%A1%9E%20-%20%E5%B1%B1%E6%9C%AC%E8%88%AA%E5%B9%B3%E3%81%AEMacBook%20Air/GitHub/mySMV/Task_image_dif_data_analysis.ipynb#Y102sZmlsZQ%3D%3D?line=2'>3</a> csp.plot_patterns(info,ch_type='eeg', units='None', size=1.5)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/decoding/csp.py:244, in CSP.fit_transform(self, X, y, **fit_params)
#     242 @copy_doc(TransformerMixin.fit_transform)
#     243 def fit_transform(self, X, y, **fit_params):  # noqa: D102
# --> 244     return super().fit_transform(X, y=y, **fit_params)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/decoding/mixin.py:33, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#      30     return self.fit(X, **fit_params).transform(X)
#      31 else:
#      32     # fit method of arity 2 (supervised transformation)
# ---> 33     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/decoding/csp.py:184, in CSP.fit(self, X, y)
#     178     raise ValueError("component_order='alternate' requires two "
#     179                      "classes, but data contains {} classes; use "
#     180                      "component_order='mutual_info' "
#     181                      "instead.".format(n_classes))
#     183 covs, sample_weights = self._compute_covariance_matrices(X, y)
# --> 184 eigen_vectors, eigen_values = self._decompose_covs(covs,
#     185                                                    sample_weights)
#     186 ix = self._order_components(covs, sample_weights, eigen_vectors,
#     187                             eigen_values, self.component_order)
#     189 eigen_vectors = eigen_vectors[:, ix]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mne/decoding/csp.py:510, in CSP._decompose_covs(self, covs, sample_weights)
#     508 n_classes = len(covs)
#     509 if n_classes == 2:
# --> 510     eigen_values, eigen_vectors = linalg.eigh(covs[0], covs.sum(0))
#     511 else:
#     512     # The multiclass case is adapted from
#     513     # http://github.com/alexandrebarachant/pyRiemann
#     514     eigen_vectors, D = _ajd_pham(covs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/linalg/_decomp.py:580, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     577     raise LinAlgError('Illegal value in argument {} of internal {}'
#     578                       ''.format(-info, drv.typecode + pfx + driver))
#     579 elif info > n:
# --> 580     raise LinAlgError('The leading minor of order {} of B is not '
#     581                       'positive definite. The factorization of B '
#     582                       'could not be completed and no eigenvalues '
#     583                       'or eigenvectors were computed.'.format(info-n))
#     584 else:
#     585     drv_err = {'ev': 'The algorithm failed to converge; {} '
#     586                      'off-diagonal elements of an intermediate '
#     587                      'tridiagonal form did not converge to zero.',
#    (...)
#     592                'evr': 'Internal Error.'
#     593                }
#
# LinAlgError: The leading minor of order 64 of B is not positive definite. The factorization of B could not be completed and no eigenvalues or eigenvectors were computed.

# %%
class_data_cspfit = csp.transform(class_data)
print(np.shape(class_data_cspfit))

# %%
# class_data_cspfit = np.reshape(class_data_cspfit,(84,4*6144))
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(class_data_cspfit,class_label, test_size=0.25,random_state=42)
model =SVC(kernel='linear')
model.fit(X_train2,Y_train2)
print(model.score(X_test2, Y_test2))

# %%
params = {
    "C":np.logspace(-2,10,13),
    "kernel":[ "poly", "rbf", "sigmoid"],
    "gamma":np.logspace(-9,3,13)
}
grid = GridSearchCV(model, params,scoring="accuracy", cv=5)

grid.fit(X_train2, Y_train2)

print("grid_best_score=",grid.best_score_)
print(grid.best_params_)

pred = grid.predict(X_test2)
print(classification_report(Y_test2, pred))

# %%
from mlxtend.plotting import plot_decision_regions
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
#PCAを用意
pca = PCA(n_components=2)
#PCAで次元圧縮
pca.fit(X_train2)
#PCAの結果を元にデータを変換
pca_X = pca.transform(X_train2)

# %%
#SVNデータの点を表示
Z = grid.predict(X_train2)

plt.scatter(pca_X[:,0], pca_X[:,1], c=Z)
plt.xlabel("x1")
plt.ylabel("x2")
