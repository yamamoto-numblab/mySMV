# %%
import os
import numpy as np
import pandas as pd
import mne
import scipy.io
import matplotlib.pyplot as plt
from scipy import signal
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from mne.decoding import CSP
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neural_network import MLPClassifier

# %%
#filePath= '/Users/yaman/Library/CloudStorage/GoogleDrive-s203192@stn.nagaokaut.ac.jp/マイドライブ/実験データ/20230519_zikken'
filePath= '/Users/yaman/Library/CloudStorage/GoogleDrive-s203192@stn.nagaokaut.ac.jp/マイドライブ/実験データ/20230529_1_zikken'

brainAdress = ['Fp1','AF7','AF3','F1','F3','F5','F7','FT7','FC5',
'FC3','FC1','C1','C3','C5','T7','TP7','CP5','CP3','CP1','P1','P3',
'P5','P7','P9','PO7','PO3','O1','Iz','Oz','POz','Pz','CPz','Fpz','Fp2',
'AF8','AF4','AFz','Fz','F2','F4','F6','F8','FT8','FC6','FC4','FC2',
'FCz','Cz','C2','C4','C6','T8','TP8','CP6','CP4','CP2','P2','P4',
'P6','P8','P10','PO8','PO4','O2']

# dataクラス
class O_Data:
    def __init__(self, eeg, index, label):
        self.eeg = eeg
        self.index = index
        self.label = label
        self.stack = []

    def push(self, item):
        self.stack.append(item)

o_data65_label1 = list()#label1のデータ
o_data = list()
label_data = list()#labelを結合したデータ


All_data = list()  # 全データを結合

def Standardization(data): #標準化
    after_data = scipy.stats.zscore(data)
    #b = np.average(after_data)
    #c = np.var(after_data)
    return after_data

file_name = list()  # すべての.matファイルの名前
for file in os.listdir(filePath):
    base, ext = os.path.splitext(file)
    if ext == '.mat':
        file_name = sorted(file_name)
        file_name.append(file)
print('Filelist')
print(file_name)
# Out:
# Filelist
# ['EEG_grasping_29-May-2023_sub1-1.mat', 'EEG_grasping_29-May-2023_sub1-2.mat', 'EEG_grasping_29-May-2023_sub2-1.mat', 'EEG_grasping_29-May-2023_sub2-2.mat', 'EEG_grasping_29-May-2023_sub2-3.mat', 'EEG_grasping_29-May-2023_sub2-4.mat', 'EEG_grasping_29-May-2023_sub3-1.mat', 'EEG_grasping_29-May-2023_sub3-2.mat', 'EEG_grasping_29-May-2023_sub3-3.mat', 'EEG_grasping_29-May-2023_sub3-4.mat', 'EEG_grasping_29-May-2023_sub3-5.mat', 'EEG_grasping_29-May-2023_sub3-6.mat']

# %%
#解析するデータを選択
file_name1 = [file_name[6],file_name[7],file_name[8],file_name[9],file_name[10],file_name[11]]
file_num1 = len(file_name1)
trial_num = 30
all_trial = len(file_name1) * trial_num
all_d = 0
CH = 64
#label1を読み込む
for s in range(file_num1):
    Dictionary = scipy.io.loadmat(filePath+"/"+file_name1[s])
    for t in range(trial_num):
        for i, key in enumerate(Dictionary.keys()):
            if i > 2:
                a = Dictionary[key]
                b = a[0, t][0][0]
                eeg = b[0][0:66, :]
                index = b[1]
                samplerate = b[2]
                label = b[5][0, 0]
                o_data = O_Data(eeg, index, label)
                o_data65_label1.append(o_data)
print("image data_loading")
# Out:
# image data_loading

# %%
c1 = o_data65_label1[0].eeg[: , 0:10240]
for n in range(len(file_name1)*trial_num-1):  # all_trial
    g1 = o_data65_label1[n+1].eeg[: , 0:10240]
    c1 = np.dstack([c1, g1])

# %%
all_data = c1.transpose(2,0,1)
print(np.shape(all_data))
all_data = all_data.astype(np.double)
# Out:
# (180, 66, 10240)

# %%
label_data = list()#labelを結合したデータ
for n in range(all_trial):
    label_data.append(o_data65_label1[n].label)
print(label_data)
print(np.shape(label_data))
# Out:
# [1, 2, 2, 1, 1, 2, 1, 3, 2, 3, 3, 1, 3, 1, 2, 2, 2, 1, 3, 2, 2, 3, 1, 2, 3, 3, 3, 1, 1, 3, 1, 1, 3, 2, 3, 2, 3, 3, 1, 3, 3, 3, 1, 2, 1, 2, 2, 3, 2, 2, 3, 1, 1, 3, 2, 2, 1, 1, 1, 2, 2, 3, 2, 1, 2, 3, 1, 2, 2, 2, 3, 3, 1, 2, 1, 3, 2, 3, 1, 2, 1, 3, 1, 3, 1, 1, 2, 3, 3, 1, 3, 2, 2, 1, 1, 1, 1, 2, 1, 1, 2, 3, 2, 2, 3, 2, 1, 3, 2, 3, 3, 1, 1, 3, 3, 2, 3, 3, 1, 2, 2, 1, 1, 3, 3, 2, 3, 1, 2, 1, 3, 2, 2, 3, 3, 1, 3, 1, 2, 2, 1, 1, 1, 3, 3, 1, 2, 3, 2, 2, 1, 2, 1, 2, 2, 3, 2, 1, 3, 1, 3, 2, 1, 3, 3, 3, 2, 1, 1, 2, 3, 2, 3, 1, 1, 3, 2, 2, 3, 1]
# (180,)

# %%
#numpy配列の定義
task1 = o_data65_label1[0].eeg[: , 0:10240]
task2 = o_data65_label1[0].eeg[: , 0:10240]
task3 = o_data65_label1[0].eeg[: , 0:10240]
for n in range(all_trial):
    if label_data[n] == 1:
        join = o_data65_label1[n].eeg[: , 0:10240]
        task1 = np.dstack([task1, join])
    if label_data[n] == 2:
        join = o_data65_label1[n].eeg[: , 0:10240]
        task2 = np.dstack([task2, join])
    if label_data[n] == 3:
        join = o_data65_label1[n].eeg[: , 0:10240]
        task3 = np.dstack([task3, join])
#task1低速度
task1_data = task1.transpose(2,0,1)
task1_data = task1_data.astype(np.double)
task1_data = np.delete(task1_data,0,axis=0)
print(np.shape(task1_data))
#task2低速度
task2_data = task2.transpose(2,0,1)
task2_data = task2_data.astype(np.double)
task2_data = np.delete(task2_data,0,axis=0)
print(np.shape(task2_data))
#task3想起なし
task3_data = task3.transpose(2,0,1)
task3_data = task3_data.astype(np.double)
task3_data = np.delete(task3_data,0,axis=0)
print(np.shape(task2_data))
# Out:
# (60, 66, 10240)
# (60, 66, 10240)
# (60, 66, 10240)

# %%
#numpy配列の定義
task1 = o_data65_label1[0].eeg[: , 0:10240]
task2 = o_data65_label1[0].eeg[: , 0:10240]
task3 = o_data65_label1[0].eeg[: , 0:10240]
for n in range(all_trial):
    if label_data[n] == 1:
        join = o_data65_label1[n].eeg[: , 0:10240]
        task1 = np.dstack([task1, join])
    if label_data[n] == 2:
        join = o_data65_label1[n].eeg[: , 0:10240]
        task2 = np.dstack([task2, join])
    if label_data[n] == 3:
        join = o_data65_label1[n].eeg[: , 0:10240]
        task3 = np.dstack([task3, join])
#task1低速度
task1_data = task1.transpose(2,0,1)
task1_data = task1_data.astype(np.double)
task1_data = np.delete(task1_data,0,axis=0)
print(np.shape(task1_data))
#task2低速度
task2_data = task2.transpose(2,0,1)
task2_data = task2_data.astype(np.double)
task2_data = np.delete(task2_data,0,axis=0)
print(np.shape(task2_data))
#task3想起なし
task3_data = task3.transpose(2,0,1)
task3_data = task3_data.astype(np.double)
task3_data = np.delete(task3_data,0,axis=0)
print(np.shape(task2_data))
# Out:
# (60, 66, 10240)
# (60, 66, 10240)
# (60, 66, 10240)

# %%
#前処理
#バターワース ローパスフィルタ
def butter_lowpass(lowcut, fs, order=4):
    '''バターワースローパスフィルタを設計する関数
    '''
    nyq = 0.5 * fs
    low = lowcut / nyq
    b, a = signal.butter(order, low, btype='low')
    return b, a
def butter_lowpass_filter(x, lowcut, fs, order=4):
    '''データにローパスフィルタをかける関数
    '''
    b, a = butter_lowpass(lowcut, fs, order=order)
    y = signal.filtfilt(b, a, x)
    return y

samplerate  = 1024
dt = 1/samplerate
passfreq = 50
for i in range(int(all_trial/3)):
    for j in range(66):
        #ローパス
        # task1_data[i][j][:] = butter_lowpass_filter(task1_data[i][j][:], passfreq, samplerate, order=4)
        # task2_data[i][j][:] = butter_lowpass_filter(task2_data[i][j][:], passfreq, samplerate, order=4)
        # task3_data[i][j][:] = butter_lowpass_filter(task3_data[i][j][:], passfreq, samplerate, order=4)
        #正規化
        task1_data[i][j] = scipy.stats.zscore(task1_data[i][j])
        task2_data[i][j] = scipy.stats.zscore(task2_data[i][j])
        task3_data[i][j] = scipy.stats.zscore(task3_data[i][j])

# %%
#顔電除去用のコピー配列
task1_data_subFaceVol = np.copy(task1_data)
task2_data_subFaceVol = np.copy(task2_data)
task3_data_subFaceVol = np.copy(task3_data)

#顔電除去(コモンアベレージリファレンスCAR)
for i in range(int(all_trial/3)):
    for j in range(64):
        task1_data_subFaceVol[i][j]= task1_data_subFaceVol[i][j]-np.mean(task1_data_subFaceVol[i],axis=0)
        task2_data_subFaceVol[i][j]= task2_data_subFaceVol[i][j]-np.mean(task2_data_subFaceVol[i],axis=0)
        task3_data_subFaceVol[i][j]= task3_data_subFaceVol[i][j]-np.mean(task3_data_subFaceVol[i],axis=0)

# %%
plt.plot(task1_data[0][0])
plt.plot(task1_data_subFaceVol[0][0])
plt.show()

# %%
# ##末尾の顔電のデータを消去
# for num in range(2):
#     np.delete(task1_data_subFaceVol,[0],1,axis=0)
#     np.delete(task2_data_subFaceVol, 64+num,axis=0)
#     np.delete(task3_data_subFaceVol, 64+num,axis=0)
# print(np.shape(task1_data_subFaceVol))

# %%
# processed_task1 = task1_data_subFaceVol[:,range(64),0:1024*4]
# processed_task2 = task2_data_subFaceVol[:,range(64),0:1024*4]
# processed_task3 = task3_data_subFaceVol[:,range(64),0:1024*4]
processed_task1 = task1_data_subFaceVol[:,range(64),1024*4:1024*10]
processed_task2 = task2_data_subFaceVol[:,range(64),1024*4:1024*10]
processed_task3 = task3_data_subFaceVol[:,range(64),1024*4:1024*10]

# %%
print(np.shape(processed_task1))
# Out:
# (60, 64, 6144)

# %%
class_data = np.concatenate([processed_task2,processed_task3])
class_data2 = np.concatenate([processed_task1,processed_task2,processed_task3])
class_data_reshape = np.reshape(class_data,(120,64*1024*6))
class_data_reshape2 = np.reshape(class_data2,(180,64*1024*6))
print(np.shape(class_data_reshape))
print(np.shape(class_data_reshape2))
# Out:
# (120, 393216)
# (180, 393216)

# %%
class_label = np.zeros(120,dtype=int)
class_label[60:] = 1
class_label2 = np.zeros(180,dtype=int)
class_label2[60:120] = 1
class_label2[120:] = 2

# %%
X_train, X_test, Y_train, Y_test = train_test_split(class_data_reshape, class_label, test_size=0.25)

model =SVC(kernel='linear')
model.fit(X_train,Y_train)

# SVC(C=1.0, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

print(model.score(X_train, Y_train))
print(model.score(X_test, Y_test))
# Out:
# 1.0
# 0.5

# %%
# Assemble a classifier
lda = LinearDiscriminantAnalysis()
#csp = CSP(n_components=2, log=None, reg=None)
csp = CSP(n_components=4, reg=None, norm_trace=False, transform_into='csp_space',cov_est='epoch')
# Use scikit-learn Pipeline with cross_val_score function
n_channels = 64
sampling_freq = 1024  # in Hertz
info = mne.create_info(ch_names=brainAdress, ch_types="eeg", sfreq=sampling_freq)
info.set_montage('biosemi64')
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF7, AF3, F1, F3, F5, F7, FT7, FC5, FC3, FC1, C1, C3, C5, ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  dig: 67 items (3 Cardinal, 64 EEG)
#  highpass: 0.0 Hz
#  lowpass: 512.0 Hz
#  meas_date: unspecified
#  nchan: 64
#  projs: []
#  sfreq: 1024.0 Hz
# >

# %%
X_train, X_test, Y_train, Y_test = train_test_split(class_data, class_label, test_size=0.7,random_state=42)

# %%
# Printing the results
class_balance = np.mean(Y_train == Y_train[0])
class_balance = max(class_balance, 1. - class_balance)
#print("Classification accuracy: %f / Chance level: %f" % (np.mean(scores),class_balance))

# plot CSP patterns estimated on full data for visualization
kenshou = csp.fit_transform(X_train, Y_train)
csp.fit_transform(X_train, Y_train)
csp.plot_patterns(info,ch_type='eeg', units='None', size=1.5)
# Out:
# Computing rank from data with rank=None
#     Using tolerance 3 (2.2e-16 eps * 64 dim * 2.1e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.3 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.8 (2.2e-16 eps * 64 dim * 1.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.1 (2.2e-16 eps * 64 dim * 2.2e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.7 (2.2e-16 eps * 64 dim * 2.6e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3 (2.2e-16 eps * 64 dim * 2.1e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8 (2.2e-16 eps * 64 dim * 2.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8 (2.2e-16 eps * 64 dim * 2.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.6e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.6e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.5 (2.2e-16 eps * 64 dim * 3.2e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.7 (2.2e-16 eps * 64 dim * 2.6e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.9 (2.2e-16 eps * 64 dim * 3.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3 (2.2e-16 eps * 64 dim * 2.1e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.3 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.8 (2.2e-16 eps * 64 dim * 1.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.1 (2.2e-16 eps * 64 dim * 2.2e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.7 (2.2e-16 eps * 64 dim * 2.6e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3 (2.2e-16 eps * 64 dim * 2.1e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8 (2.2e-16 eps * 64 dim * 2.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8 (2.2e-16 eps * 64 dim * 2.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.6e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.6e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.5 (2.2e-16 eps * 64 dim * 3.2e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.7 (2.2e-16 eps * 64 dim * 2.6e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.9 (2.2e-16 eps * 64 dim * 3.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# <MNEFigure size 1125x287.5 with 5 Axes>
# <MNEFigure size 1125x287.5 with 5 Axes>

# %%
print(np.shape(kenshou))
# Out:
# (36, 4, 6144)

# %%
class_data_cspfit = csp.transform(X_test)
class_data_cspfit = np.reshape(class_data_cspfit,(84,4*6144))
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(class_data_cspfit,Y_test, test_size=0.25,random_state=42)

model.fit(X_train2,Y_train2)
print(model.score(X_test2, Y_test2))
# Out:
# 0.38095238095238093

# %%
params = {
    "C":np.arange(0.1,1,0.05),
    "kernel":["linear", "poly", "rbf", "sigmoid"],
    "gamma":np.arange(0.0001,0.1,0.05)
}
grid = GridSearchCV(model, params,scoring="accuracy", cv=3)

grid.fit(X_train2, Y_train2)

print(grid.best_score_)
print(grid.best_params_)

pred = grid.predict(X_test2)
print(classification_report(Y_test2, pred))
# Out:
# 0.6825396825396824
# {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
#               precision    recall  f1-score   support
#
#            0       0.44      0.64      0.52        11
#            1       0.20      0.10      0.13        10
#
#     accuracy                           0.38        21
#    macro avg       0.32      0.37      0.33        21
# weighted avg       0.32      0.38      0.34        21

# %%
# 多層パーセプトロン
mlp_clf2 = MLPClassifier()
mlp_clf2.fit(X_train2, Y_train2)
mlp_clf2.score(X_test2, Y_test2)
# Out:
# 0.42857142857142855

# %%
random_search = {'batch_size': [10, 20, 30, 130],
               'hidden_layer_sizes': [(150, 150), (100, 100, 50), (150, 100, 50)],
               'max_iter': [400, 500, 600, 700, 800],
               'random_state': [0]}
mlp_random_search2 = RandomizedSearchCV(mlp_clf2, random_search, cv=3,
                                   n_jobs=-1, scoring='accuracy', random_state=0)
# スケーリングしたデータで実行します
mlp_random_search2.fit(X_train2, Y_train2)
# Out:
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=MLPClassifier(), n_jobs=-1,
#                    param_distributions={'batch_size': [10, 20, 30, 130],
#                                         'hidden_layer_sizes': [(150, 150),
#                                                                (100, 100, 50),
#                                                                (150, 100, 50)],
#                                         'max_iter': [400, 500, 600, 700, 800],
#                                         'random_state': [0]},
#                    random_state=0, scoring='accuracy')

# %%
# 実行
cvres = mlp_random_search2.cv_results_
for score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(score, params)
# Out:
# 0.5873015873015873 {'random_state': 0, 'max_iter': 500, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 20}
# 0.5873015873015873 {'random_state': 0, 'max_iter': 400, 'hidden_layer_sizes': (100, 100, 50), 'batch_size': 30}
# 0.6984126984126983 {'random_state': 0, 'max_iter': 800, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 130}
# 0.5873015873015873 {'random_state': 0, 'max_iter': 700, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 20}
# 0.6190476190476191 {'random_state': 0, 'max_iter': 500, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 10}
# 0.7142857142857143 {'random_state': 0, 'max_iter': 600, 'hidden_layer_sizes': (150, 150), 'batch_size': 10}
# 0.6507936507936508 {'random_state': 0, 'max_iter': 800, 'hidden_layer_sizes': (150, 150), 'batch_size': 30}
# 0.6984126984126983 {'random_state': 0, 'max_iter': 700, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 130}
# 0.6031746031746031 {'random_state': 0, 'max_iter': 400, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 30}
# 0.6190476190476191 {'random_state': 0, 'max_iter': 600, 'hidden_layer_sizes': (100, 100, 50), 'batch_size': 20}

# %%
#3クラス分類
X_train3, X_test3, Y_train3, Y_test3 = train_test_split(class_data2,class_label2, test_size=0.75,random_state=42)

# %%
# Printing the results
class_balance = np.mean(Y_train3 == Y_train3[0])
class_balance = max(class_balance, 1. - class_balance)
#print("Classification accuracy: %f / Chance level: %f" % (np.mean(scores),class_balance))

# plot CSP patterns estimated on full data for visualization
kenshou2 = csp.fit_transform(X_train3, Y_train3)
csp.fit_transform(X_train3, Y_train3)
csp.plot_patterns(info,ch_type='eeg', units='None', size=1.5)
# Out:
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8 (2.2e-16 eps * 64 dim * 2.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.4 (2.2e-16 eps * 64 dim * 3.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8 (2.2e-16 eps * 64 dim * 2.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.7 (2.2e-16 eps * 64 dim * 1.2e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5 (2.2e-16 eps * 64 dim * 3.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2 (2.2e-16 eps * 64 dim * 3.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.9 (2.2e-16 eps * 64 dim * 3.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2 (2.2e-16 eps * 64 dim * 2.2e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5 (2.2e-16 eps * 64 dim * 3.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5 (2.2e-16 eps * 64 dim * 3.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.8 (2.2e-16 eps * 64 dim * 1.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8 (2.2e-16 eps * 64 dim * 2.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.4 (2.2e-16 eps * 64 dim * 3.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8 (2.2e-16 eps * 64 dim * 2.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.7 (2.2e-16 eps * 64 dim * 1.2e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5 (2.2e-16 eps * 64 dim * 3.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2 (2.2e-16 eps * 64 dim * 3.7e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4 (2.2e-16 eps * 64 dim * 2.4e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.9 (2.2e-16 eps * 64 dim * 3.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2 (2.2e-16 eps * 64 dim * 2.2e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5 (2.2e-16 eps * 64 dim * 3.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6 (2.2e-16 eps * 64 dim * 2.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1 (2.2e-16 eps * 64 dim * 2.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5 (2.2e-16 eps * 64 dim * 3.5e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3 (2.2e-16 eps * 64 dim * 2.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6 (2.2e-16 eps * 64 dim * 3.3e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.8 (2.2e-16 eps * 64 dim * 1.9e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4 (2.2e-16 eps * 64 dim * 2.8e+14  max singular value)
#     Estimated rank (mag): 64
#     MAG: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating covariance using EMPIRICAL
# Done.
# <MNEFigure size 1125x287.5 with 5 Axes>
# <MNEFigure size 1125x287.5 with 5 Axes>

# %%
class_data_cspfit2 = csp.transform(X_test3)
print(np.shape(class_data_cspfit2))
class_data_cspfit2 = np.reshape(class_data_cspfit2,(135,4*6144))
X_train4, X_test4, Y_train4, Y_test4 = train_test_split(class_data_cspfit2,Y_test3, test_size=0.25,random_state=42)
# Out:
# (135, 4, 6144)

# %%
# 多層パーセプトロン
mlp_clf = MLPClassifier()
mlp_clf.fit(X_train4, Y_train4)
mlp_clf.score(X_test4, Y_test4)
# Out:
# 0.2647058823529412

# %%
random_search = {'batch_size': [10, 20, 30, 130],
               'hidden_layer_sizes': [(150, 150), (100, 100, 50), (150, 100, 50)],
               'max_iter': [400, 500, 600, 700, 800],
               'random_state': [0]}
mlp_random_search = RandomizedSearchCV(mlp_clf, random_search, cv=3,
                                   n_jobs=-1, scoring='accuracy', random_state=0)
# スケーリングしたデータで実行します
mlp_random_search.fit(X_train4, Y_train4)
# Out:
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# /Users/yaman/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:621: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=MLPClassifier(), n_jobs=-1,
#                    param_distributions={'batch_size': [10, 20, 30, 130],
#                                         'hidden_layer_sizes': [(150, 150),
#                                                                (100, 100, 50),
#                                                                (150, 100, 50)],
#                                         'max_iter': [400, 500, 600, 700, 800],
#                                         'random_state': [0]},
#                    random_state=0, scoring='accuracy')

# %%
# 実行
cvres = mlp_random_search.cv_results_
for score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(score, params)
# Out:
# 0.3175876411170529 {'random_state': 0, 'max_iter': 500, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 20}
# 0.35828877005347587 {'random_state': 0, 'max_iter': 400, 'hidden_layer_sizes': (100, 100, 50), 'batch_size': 30}
# 0.39661319073083784 {'random_state': 0, 'max_iter': 800, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 130}
# 0.3175876411170529 {'random_state': 0, 'max_iter': 700, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 20}
# 0.26737967914438504 {'random_state': 0, 'max_iter': 500, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 10}
# 0.34670231729055256 {'random_state': 0, 'max_iter': 600, 'hidden_layer_sizes': (150, 150), 'batch_size': 10}
# 0.27777777777777773 {'random_state': 0, 'max_iter': 800, 'hidden_layer_sizes': (150, 150), 'batch_size': 30}
# 0.39661319073083784 {'random_state': 0, 'max_iter': 700, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 130}
# 0.3672014260249554 {'random_state': 0, 'max_iter': 400, 'hidden_layer_sizes': (150, 100, 50), 'batch_size': 30}
# 0.3279857397504456 {'random_state': 0, 'max_iter': 600, 'hidden_layer_sizes': (100, 100, 50), 'batch_size': 20}
